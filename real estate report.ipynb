# %% [markdown]
# # DSE 200 FINAL PROJECT
# ## Fall 2022
# ### Author: __Peng Cheng__
# ### Topic: Analysis of Factors Affecting Single-Family Home Prices in Los Angeles County
# ### Date:  December 2nd, 2022

# %% [markdown]
# <a id='0'></a>
# ## Table of contents

# %% [markdown]
# * [Analysis of Factors Affecting Single-Family Home Prices in Los Angeles County](#2)<br>
#     * [Step 1: Find a dataset or datasets](#2.1)<br>
#         * [2.1.1 Import Libraries](#2.1.1)<br>
#         * [2.1.2 Ingest Datasets](#2.1.2)<br>
#     * [Step 2: Explore the datasets](#2.2)<br>
#         * [2.2.1 Use the pandas Library to Explore Raw Data](#2.2.1)<br>
#             * [2.2.1.1 Median Prices of Existing Single Family Homes in California datsset(1990-2022)](#2.2.1.1)<br>
#                 * [2.2.1.1.1 Explore Raw Data](#2.2.1.1.1)<br>
#                 * [2.2.1.1.2 Findings from Raw Data Exploration](#2.2.1.1.2)<br>
#             * [2.2.1.2 Resident Population in Los Angeles County datsset(1970-2022)](#2.2.1.2)<br>
#                 * [2.2.1.2.1 Explore Raw Data](#2.2.1.2.1)<br>
#                 * [2.2.1.2.2 Findings from Raw Data Exploration](#2.2.1.2.2)<br>
#             * [2.2.1.3 New Private Housing Structures Authorized by Building Permits for Los Angeles County datsset(1990-2022)](#2.2.1.3)<br>
#                 * [2.2.1.3.1 Explore Raw Data](#2.2.1.3.1)<br>
#                 * [2.2.1.3.2 Findings from Raw Data Exploration](#2.2.1.3.2)<br>
#             * [2.2.1.4 30-Year Fixed Rate Mortgage Average in the United States datsset(1971-2022)](#2.2.1.4)<br>
#                 * [2.2.1.4.1 Explore Raw Data](#2.2.1.4.1)<br>
#                 * [2.2.1.4.2 Findings from Raw Data Exploration](#2.2.1.4.2)<br>
#             * [2.2.1.5 Per Capita Personal Income in Los Angeles County datsset(1969-2020)](#2.2.1.5)<br>
#                 * [2.2.1.5.1 Explore Raw Data](#2.2.1.5.1)<br>
#                 * [2.2.1.5.2 Findings from Raw Data Exploration](#2.2.1.5.2)<br>
#             * [2.2.1.6 World consumer price index datsset(1960-2021)](#2.2.1.6)<br>
#                 * [2.2.1.6.1 Explore Raw Data](#2.2.1.6.1)<br>
#                 * [2.2.1.6.2 Findings from Raw Data Exploration](#2.2.1.6.2)<br>
#         * [2.2.2 Use the matplotlib Library to Visualize Data](#2.2.2)<br>
#             * [2.2.2.1 Briefly Transform Raw Data to Make Raw Data Plot Readable](#2.2.2.1)<br>
#             * [2.2.2.2 Plot Raw Data](#2.2.2.2)<br>
#             * [2.2.2.3 Findings from Raw Data Ploting](#2.2.2.3)<br>
#     * [Step 3: Identify 1-3 research questions and perform analysis](#2.3)<br>
#         * [2.3.1 Research Questions](#2.3.1)<br>
#         * [2.3.2 Perform Analysis](#2.3.2)<br>
#             * [2.3.2.1 Clean and Transform Datasets](#2.3.2.1)<br>
#             * [2.3.2.2 Plot Cleaned and Transformed Datasets](#2.3.2.2)<br>
#             * [2.3.2.3 Merge Six Datasets](#2.3.2.3)<br>
#             * [2.3.2.4 Solving Question 1](#2.3.2.4)<br>
#                 * [2.3.2.4.1 Analyse Long-term Correlation of Each Features](#2.3.2.4.1)<br>
#                 * [2.3.2.4.2 Analyse Medium-term Correlation of Each Features](#2.3.2.4.2)<br>
#                 * [2.3.2.4.3 Analyse Short-term Correlation of Each Features](#2.3.2.4.3)<br>
#                 * [2.3.2.4.4 why particular methods were chosen](#2.3.2.4.4)<br>
#             * [2.3.2.5 Solving Question 2](#2.3.2.5)<br>
#                 * [2.3.2.5.1 Transform Data](#2.3.2.5.1)<br>
#                 * [2.3.2.5.2 Build Learning Model](#2.3.2.5.2)<br>
#                 * [2.3.2.5.3 why particular methods were chosen](#2.3.2.5.3)<br>
#     * [Step 4: Present Your Findings](#2.4)<br>
#         * [2.4.1 Findings for Question 1](#2.4.1)<br>
#             * [2.4.1.1 Plot Long-term Correlation of Each Features](#2.4.1.1)<br>
#             * [2.4.1.2 Plot Medium-term Correlation of Each Features](#2.4.1.2)<br>
#             * [2.4.1.3 Plot Short-term Correlation of Each Features](#2.4.1.3)<br>
#             * [2.4.1.4 Summary of Question 1 Analysis](#2.4.1.4)<br>
#         * [2.4.2 Findings for Question 2](#2.4.2)<br>
#             * [2.4.2.1 Plot Learning Model](#2.4.2.1)<br>
#             * [2.4.2.2 Predict Data](#2.4.2.2)<br>
#             * [2.4.2.3 Summary of Question 2 Analysis](#2.4.2.3)<br>
#         * [2.4.3 Limitations of Analysis](#2.4.3)<br>

# %%
import numpy as np

# %% [markdown]
# <a id='2.1'></a>
# ## Step 1: Find a dataset or datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>
# Based on your interest, identify a dataset which you will want to examine.  You will find a starting point for where you can find open datasets at the end of this notebook, but feel free to use other datasets you have access to and can publicly share results about.
#
#
# This step may take some time, as you’ll likely look at a number of datasets before you find one (or more) which holds promising data for the kinds of questions you want to ask. You are expected to use at least two interconnected datasets, e.g., two tables in one database or a combination of datasets which you can merge in some meaningful way.

# %%
#EXPLAIN AND INGEST YOUR DATASET IN THIS SECTION

# %% [markdown]
# <a id='2.1.1'></a>
# ### 2.1.1 Import Libraries
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# %% [markdown]
# <a id='2.1.2'></a>
# ### 2.1.2 Ingest Datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_median = pd.read_excel('./MedianPricesofExistingDetachedHomesHistoricalData.xls',header=7)
## Median Prices of Existing Single Family Homes in California datsset(1990-2022)
## From Public database of California Association of Realtors (https://www.car.org/marketdata/data)

df_population = pd.read_csv('https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=CALOSA7POP&scale=left&cosd=1970-01-01&coed=2021-01-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Annual&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-11-30&revision_date=2022-11-30&nd=1970-01-01')
## Resident Population in Los Angeles County (1970-2022)
## From Public economic database of Federal Reserve Bank St. Louis datsset(https://fred.stlouisfed.org)

df_new_build = pd.read_csv('https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=BPPRIV006037&scale=left&cosd=1990-01-01&coed=2021-01-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Annual&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-11-30&revision_date=2022-11-30&nd=1990-01-01')
## New Private Housing Structures Authorized by Building Permits for Los Angeles County datsset(1990-2022)
## From Public economic database of Federal Reserve Bank St. Louis (https://fred.stlouisfed.org)

df_mortgage = pd.read_csv('https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=MORTGAGE30US&scale=left&cosd=1971-04-02&coed=2022-11-23&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Weekly%2C%20Ending%20Thursday&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-11-30&revision_date=2022-11-30&nd=1971-04-02')
## 30-Year Fixed Rate Mortgage Average in the United States datsset(1971-2022)
## From Public economic database of Federal Reserve Bank St. Louis (https://fred.stlouisfed.org)

df_pcpi = pd.read_csv('https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=PCPI06037&scale=left&cosd=1969-01-01&coed=2021-01-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Annual&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2022-11-30&revision_date=2022-11-30&nd=1969-01-01')
## Per Capita Personal Income in Los Angeles County datsset(1969-2020)
## From Public economic database of Federal Reserve Bank St. Louis (https://fred.stlouisfed.org)

df_cpi = pd.read_excel('./API_FP.CPI.TOTL.ZG_DS2_en_excel_v2_4701305.xls',header=3,index_col=0)
## World Consumer Price Index datsset(1960-2021)
## From Public database of The World Bank (https://data.worldbank.org/)

# %% [markdown]
# Click this [link](https://car.sharefile.com/d-s0c02663a5c54e23a) to download Median Prices of Existing Single Family Homes in California dataset(1990-2022).
#
# Click this [link](https://api.worldbank.org/v2/en/indicator/FP.CPI.TOTL.ZG?downloadformat=excel) to download World Consumer Price Index dataset(1960-2021).

# %% [markdown]
# <a id='2.2'></a>
# ## Step 2: Explore the datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>
# In this step, you should explore what is present in the data and how the data is organized. You’ll need to determine what common features allow you to merge the datasets.
#
# You are expected to answer the following questions using the _pandas_ library and markdown cells to describe your actions:
#
# * Are there quality issues in the dataset (noisy, missing data, etc.)?
# * What will you need to do to clean and/or transform the raw data for analysis?
#
# You are also expected to use the _matplotlib_ library to visually explore the datasets and explain your findings, specifically,
#
# * How are the data distributed?
# * What are some common trends?
# * What are the relationships between variables in your datasets?

# %%
#PERFORM AND EXPLAIN YOUR EXPLORATORY ANALYSIS IN THIS SECTION

# %% [markdown]
# <a id='2.2.1'></a>
# ### 2.2.1 Use the _pandas_ Library to Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.1'></a>
# #### 2.2.1.1 Median Prices of Existing Single Family Homes in California datsset(1990-2022)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.1.1'></a>
# ##### 2.2.1.1.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of contents](#0)</div></sub>

# %%
df_median.shape
## check the shape of df_median
# Out:
# (394, 62)

# %%
df_median.info()
## Check the information of df_median
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 62 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mon-Yr           394 non-null    datetime64[ns]
#  1   CA               394 non-null    float64
#  2   Alameda          394 non-null    float64
#  3   Amador           224 non-null    float64
#  4   Butte            394 non-null    float64
#  5   Calaveras        262 non-null    float64
#  6   Contra-Costa     202 non-null    float64
#  7   Del Norte        166 non-null    float64
#  8   El Dorado        166 non-null    float64
#  9   Fresno           394 non-null    float64
#  10  Glenn            202 non-null    float64
#  11  Humboldt         394 non-null    float64
#  12  Kern             394 non-null    int64
#  13  Kings            202 non-null    float64
#  14  Lake             346 non-null    float64
#  15  Lassen           82 non-null     float64
# ...

# %%
df_median.isna().sum().sum()
## Count NaN/Null values of df_median
# Out:
# 5235

# %%
df_median['Los Angeles'].isna().sum().sum()
# Out:
# 0

# %%
df_median.head(10)
## Check the top 3 rows of df_median
# Out:
#       Mon-Yr        CA        Alameda  Amador          Butte  Calaveras  \
# 0 1990-01-01  194952.0  226148.902299     NaN  102142.750000        NaN
# 1 1990-02-01  196273.0  219306.000000     NaN   83333.000000        NaN
# 2 1990-03-01  194856.0  225162.000000     NaN  100000.000000        NaN
# 3 1990-04-01  196111.0  229333.000000     NaN  107999.600000        NaN
# 4 1990-05-01  195281.0  232291.000000     NaN  100000.000000        NaN
# 5 1990-06-01  194410.0  231250.000000     NaN  123043.326087        NaN
# 6 1990-07-01  193088.0  232916.000000     NaN  113570.750000        NaN
# 7 1990-08-01  192180.0  228467.000000     NaN  113332.666667        NaN
# 8 1990-09-01  189979.0  225000.000000     NaN  117499.125000        NaN
# 9 1990-10-01  187630.0  221093.000000     NaN  127142.500000        NaN
#
#    Contra-Costa  Del Norte  El Dorado        Fresno  ...  Yuba  Unnamed: 53  \
# 0           NaN        NaN        NaN  82083.125000  ...   NaN          NaN
# ...

# %%
df_median.tail(3)
## Check the end 3 rows of df_median
# Out:
#         Mon-Yr        CA    Alameda    Amador     Butte  Calaveras  \
# 391 2022-08-01  839460.0  1230000.0  447450.0  441000.0   464950.0
# 392 2022-09-01  821680.0  1240000.0  400000.0  429780.0   450000.0
# 393 2022-10-01  801190.0  1250000.0  365000.0  438750.0   414500.0
#
#      Contra-Costa  Del Norte  El Dorado    Fresno  ...      Yuba  Unnamed: 53  \
# 391      870000.0   378960.0   631000.0  405000.0  ...  422500.0          NaN
# 392      882000.0   418750.0   647450.0  415000.0  ...  435000.0          NaN
# 393      867000.0   389900.0   684000.0  400000.0  ...  405000.0          NaN
#
#         Condo  LA Metro  Central Coast  Central Valley  Far North  \
# 391  625000.0  765000.0       950000.0        460000.0   380000.0
# 392  620000.0  750000.0       920000.0        456000.0   380000.0
# 393  625000.0  742570.0       937500.0        450000.0   394000.0
#
#      Inland Empire  S.F. Bay Area     SoCal
# 391       565500.0      1250000.0  795000.0
# ...

# %% [markdown]
# <a id='2.2.1.1.2'></a>
# ##### 2.2.1.1.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 393 rows and 63 columns in the dataset.
#
# __Data format:__
# The ‘Mon-Yr’ column (Date) format is Datetime.
# Other columns (Median prices of each counties) format are float or int.
#
# __Data interval :__
# monthly.
#
# __quality issues:__
# There are 5235 NaN/Null Values in the dataset, but the useful columns do not have NaN/Null Value.
#
# __Anything to do to clean and/or transform?__
# Drop useless column, and wait to be merged by other dateset.

# %% [markdown]
# <a id='2.2.1.2'></a>
# #### 2.2.1.2 Resident Population in Los Angeles County datsset(1970-2022)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.2.1'></a>
# ##### 2.2.1.2.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_population.shape
## check the shape of df_population
# Out:
# (52, 2)

# %%
df_population.info()
## Check the information of df_population
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        52 non-null     object
#  1   CALOSA7POP  52 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 960.0+ bytes

# %%
df_population.isna().sum()
## Count NaN/Null values of df_population
# Out:
# DATE          0
# CALOSA7POP    0
# dtype: int64

# %%
df_population['CALOSA7POP'].isna().sum()
## Count NaN/Null values in useful column of df_population
# Out:
# 0

# %%
df_population.head(3)
## Check the top 3 rows of df_population
# Out:
#          DATE  CALOSA7POP
# 0  1970-01-01    7041.982
# 1  1971-01-01    7103.600
# 2  1972-01-01    7056.600

# %%
df_population.tail(3)
## Check the end 3 rows of df_population
# Out:
#           DATE  CALOSA7POP
# 49  2019-01-01   10011.602
# 50  2020-01-01    9989.165
# 51  2021-01-01    9829.544

# %% [markdown]
# <a id='2.2.1.2.2'></a>
# ##### 2.2.1.2.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 53 rows and 2 columns in the dataset.
#
# __Data format:__
# The ‘DATE’ column (Date) format is String.
# 'CALOSA7POP’ Column (Resident Population, Thousands of persons) format is Float.
#
# __Data interval :__
# yearly.
#
# __quality issues:__
# There are no NaN/Null Values in the dataset.
#
# __Anything to do to clean and/or transform?__
# Format ‘DATE’ column to Datetime, and convert the data to monthly.

# %% [markdown]
# <a id='2.2.1.3'></a>
# #### 2.2.1.3 New Private Housing Structures Authorized by Building Permits for Los Angeles County datsset(1990-2022)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.3.1'></a>
# ##### 2.2.1.3.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_new_build.shape
## check the shape of df_new_build
# Out:
# (32, 2)

# %%
df_new_build.info()
## Check the information of df_new_build
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          32 non-null     object
#  1   BPPRIV006037  32 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 640.0+ bytes

# %%
df_new_build.isna().sum()
## Count NaN/Null values of df_new_build
# Out:
# DATE            0
# BPPRIV006037    0
# dtype: int64

# %%
df_new_build['BPPRIV006037'].isna().sum()
## Count NaN/Null values in useful column of df_new_build
# Out:
# 0

# %%
df_new_build.head(3)
## Check the top 3 rows of df_new_build
# Out:
#          DATE  BPPRIV006037
# 0  1990-01-01       25125.0
# 1  1991-01-01       15914.0
# 2  1992-01-01       11965.0

# %%
df_new_build.tail(3)
## Check the end 3 rows of df_new_build
# Out:
#           DATE  BPPRIV006037
# 29  2019-01-01       21565.0
# 30  2020-01-01       20903.0
# 31  2021-01-01       23284.0

# %% [markdown]
# <a id='2.2.1.3.2'></a>
# ##### 2.2.1.3.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 33 rows and 2 columns in the dataset.
#
# __Data format:__
# The ‘DATE’ column (Date) format is String.
# 'BPPRIV006037’ Column (Number of new Units built this year) format is Float.
#
# __Data interval :__
# yearly.
#
# __quality issues:__
# There are no NaN/Null Values in the dataset.
#
# __Anything to do to clean and/or transform?__
# Format ‘DATE’ column to Datetime, and convert the data to monthly.

# %% [markdown]
# <a id='2.2.1.4'></a>
# #### 2.2.1.4 30-Year Fixed Rate Mortgage Average in the United States datsset(1971-2022)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.4.1'></a>
# ##### 2.2.1.4.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_mortgage.shape
## check the shape of df_mortgage
# Out:
# (2696, 2)

# %%
df_mortgage.info()
## Check the information of df_mortgage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2696 entries, 0 to 2695
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DATE          2696 non-null   object
#  1   MORTGAGE30US  2696 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 42.2+ KB

# %%
df_mortgage.isna().sum()
## Count NaN/Null values of df_mortgage
# Out:
# DATE            0
# MORTGAGE30US    0
# dtype: int64

# %%
df_mortgage['MORTGAGE30US'].isna().sum()
## Count NaN/Null values in useful column of df_mortgage
# Out:
# 0

# %%
df_mortgage.head(3)
## Check the top 3 rows of df_mortgage
# Out:
#          DATE  MORTGAGE30US
# 0  1971-04-02          7.33
# 1  1971-04-09          7.31
# 2  1971-04-16          7.31

# %%
df_mortgage.tail(3)
## Check the end 3 rows of df_mortgage
# Out:
#             DATE  MORTGAGE30US
# 2693  2022-11-10          7.08
# 2694  2022-11-17          6.61
# 2695  2022-11-23          6.58

# %% [markdown]
# <a id='2.2.1.4.2'></a>
# ##### 2.2.1.4.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 2694 rows and 2 columns in the dataset.
#
# __Data format:__
# The ‘DATE’ column (Date) format is String.
# 'MORTGAGE30US’ Column (Mortgage interest of the week) format is Float.
#
# __Data interval :__
# Weekly.
#
# __quality issues:__
# There are no NaN/Null Values in the dataset.
#
# __Anything to do to clean and/or transform?__
# Format ‘DATE’ column to Datetime, and convert the data to monthly.

# %% [markdown]
# <a id='2.2.1.5'></a>
# #### 2.2.1.5 Per Capita Personal Income in Los Angeles County datsset(1969-2020)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.5.1'></a>
# ##### 2.2.1.5.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_pcpi.shape
## check the shape of df_pcpi
# Out:
# (53, 2)

# %%
df_pcpi.info()
## Check the information of df_pcpi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       53 non-null     object
#  1   PCPI06037  53 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 976.0+ bytes

# %%
df_pcpi.isna().sum()
## Count NaN/Null values of df_pcpi
# Out:
# DATE         0
# PCPI06037    0
# dtype: int64

# %%
df_pcpi['PCPI06037'].isna().sum()
## Count NaN/Null values in useful column of df_pcpi
# Out:
# 0

# %%
df_pcpi.head(3)
## Check the top 3 rows of df_pcpi
# Out:
#          DATE  PCPI06037
# 0  1969-01-01       4819
# 1  1970-01-01       5059
# 2  1971-01-01       5226

# %%
df_pcpi.tail(3)
## Check the end 3 rows of df_pcpi
# Out:
#           DATE  PCPI06037
# 50  2019-01-01      63252
# 51  2020-01-01      68541
# 52  2021-01-01      74141

# %% [markdown]
# <a id='2.2.1.5.2'></a>
# ##### 2.2.1.5.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 54 rows and 2 columns in the dataset.
#
# __Data format:__
# The ‘DATE’ column (Date) format is String.
# 'PCPI06037’ Column (Per Capita Personal Income of the year) format is Float.
#
# __Data interval :__
# yearly.
#
# __quality issues:__
# There are no NaN/Null Values in the dataset.
#
# __Anything to do to clean and/or transform?__
# Format ‘DATE’ column to Datetime, and convert the data to monthly.

# %% [markdown]
# <a id='2.2.1.6'></a>
# #### 2.2.1.6 World consumer price index datsset(1960-2021)
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.1.6.1'></a>
# ##### 2.2.1.6.1 Explore Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
df_cpi.shape
## check the shape of df_cpi
# Out:
# (266, 65)

# %%
df_cpi.info()
## Check the information of df_cpi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 266 entries, Aruba to Zimbabwe
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Code    266 non-null    object
#  1   Indicator Name  266 non-null    object
#  2   Indicator Code  266 non-null    object
#  3   1960            70 non-null     float64
#  4   1961            72 non-null     float64
#  5   1962            74 non-null     float64
#  6   1963            75 non-null     float64
#  7   1964            79 non-null     float64
#  8   1965            86 non-null     float64
#  9   1966            93 non-null     float64
#  10  1967            100 non-null    float64
#  11  1968            101 non-null    float64
#  12  1969            102 non-null    float64
#  13  1970            107 non-null    float64
#  14  1971            111 non-null    float64
#  15  1972            114 non-null    float64
# ...

# %%
df_cpi.isna().sum()
## Count NaN/Null values of df_cpi
# Out:
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              196
# 1961              194
#                  ...
# 2017               39
# 2018               42
# 2019               44
# 2020               53
# 2021               74
# Length: 65, dtype: int64

# %%
df_cpi.T['United States'].isna().sum().sum()
## Count NaN/Null values in useful column of df_cpi
# Out:
# 0

# %%
df_cpi.head(3)
## Check the top 3 rows of df_cpi
# Out:
#                             Country Code  \
# Country Name
# Aruba                                ABW
# Africa Eastern and Southern          AFE
# Afghanistan                          AFG
#
#                                                     Indicator Name  \
# Country Name
# Aruba                        Inflation, consumer prices (annual %)
# Africa Eastern and Southern  Inflation, consumer prices (annual %)
# Afghanistan                  Inflation, consumer prices (annual %)
#
#                              Indicator Code  1960  1961  1962  1963  1964  \
# Country Name
# Aruba                        FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN
# Afghanistan                  FP.CPI.TOTL.ZG   NaN   NaN   NaN   NaN   NaN
#
#                              1965  1966  ...      2012      2013      2014  \
# Country Name                             ...
# ...

# %%
df_cpi.tail(3)
## Check the end 3 rows of df_cpi
# Out:
#              Country Code                         Indicator Name  \
# Country Name
# South Africa          ZAF  Inflation, consumer prices (annual %)
# Zambia                ZMB  Inflation, consumer prices (annual %)
# Zimbabwe              ZWE  Inflation, consumer prices (annual %)
#
#               Indicator Code      1960      1961      1962     1963      1964  \
# Country Name
# South Africa  FP.CPI.TOTL.ZG  1.288859  2.102374  1.246285  1.33797  2.534973
# Zambia        FP.CPI.TOTL.ZG       NaN       NaN       NaN      NaN       NaN
# Zimbabwe      FP.CPI.TOTL.ZG       NaN       NaN       NaN      NaN       NaN
#
#                   1965      1966  ...      2012      2013      2014  \
# Country Name                      ...
# South Africa  4.069029  3.489234  ...  5.724658  5.784469  6.129838
# Zambia             NaN       NaN  ...  6.575900  6.977676  7.806876
# Zimbabwe           NaN       NaN  ...  3.725327  1.634950 -0.197785
#
# ...

# %%
df_cpi.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %% [markdown]
# <a id='2.2.1.6.2'></a>
# ##### 2.2.1.6.2 Findings from Raw Data Exploration
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# __Data volumn:__
# There are 266 rows and 65 columns in the dataset.
#
# __Data format:__
# ‘Country name’ column is index,
# ‘Country code’ column format is String
# ‘Indicator name’ column format is String
# ‘Indicator code’ column format is String
# Other columns (Years) format are: Float
#
# __Data interval :__
# yearly.
#
# __quality issues:__
# There are 6001 NaN/Null Values in the dataset,but the useful columns(rows) do not have NaN/Null Value.
#
# __Anything to do to clean and/or transform?__<br>
# Transform the data, format ‘DATE’ from column name to Datetime format, drop useless rows and convert the data to monthly.<br>
# The data is percentage index, may need to transform to base value index later to improve linear correlation with home price data.

# %% [markdown]
# <a id='2.2.2'></a>
# ### 2.2.2 Use the _matplotlib_ Library to Visualize Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.2.2.1'></a>
# #### 2.2.2.1 Briefly Transform Raw Data to Make Raw Data Plot Readable
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## just brief ajust data to plot datasets, no data cleaning or major transform

df_median=df_median.rename(columns={'Los Angeles':'median','Mon-Yr':'date'})
df_median['date']=pd.to_datetime(df_median['date'])
df_median['median']=df_median['median'].astype(float)
## Rename useful column and convert date format of df_median

df_population=df_population.rename(columns={'CALOSA7POP':'population','DATE':'date'})
df_population['date']=pd.to_datetime(df_population['date'])
## Rename useful column and convert date format of df_population

df_new_build=df_new_build.rename(columns={'BPPRIV006037':'new_build','DATE':'date'})
df_new_build['date']=pd.to_datetime(df_new_build['date'])
## Rename useful column and convert date format of df_new_build

df_mortgage=df_mortgage.rename(columns={'MORTGAGE30US':'mortgage','DATE':'date'})
df_mortgage['date']=pd.to_datetime(df_mortgage['date'])
## Rename useful column and convert date format of df_mortgage

df_pcpi=df_pcpi.rename(columns={'PCPI06037':'pcpi','DATE':'date'})
df_pcpi['date']=pd.to_datetime(df_pcpi['date'])
## Rename useful column and convert date format of df_pcpi

df_cpi=df_cpi.T
## tranform dataset to make year in index and country name in column
df_cpi.drop(['Country Code', 'Indicator Name','Indicator Code'],axis=0,inplace=True)
## drop useless column
df_cpi.reset_index(inplace=True)
# extract date column out into a column
df_cpi['date']=pd.to_datetime(df_cpi['index'])
## formate date column and rename to 'date'
df_cpi=df_cpi.rename(columns={'United States':'cpi'})
## Rename useful column and convert date format of df_cpi

# %% [markdown]
# <a id='2.2.2.2'></a>
# #### 2.2.2.2 Plot Raw Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## plor raw data to help make next step decition

fig = plt.figure(figsize =([10, 20]))
 
gs = plt.GridSpec(6, 6)
gs.update(wspace = 2, hspace =0.4)
 
ax1 = plt.subplot(gs[0, :3])
ax1.plot(df_median['date'],df_median['median'])
ax1.set_title('Median Prices of Existing Single Family Homes in Los Angeles county', fontsize = 9)
ax1.set_xlabel('Year', fontsize = 9)
ax1.set_ylabel('median', fontsize = 9)

ax2 = plt.subplot(gs[0, 3:6])
ax2.plot(df_population['date'],df_population['population'])
ax2.set_title('Resident Population in Los Angeles County', fontsize = 9)
ax2.set_xlabel('Year', fontsize = 9)
ax2.set_ylabel('Thousands of Persons', fontsize = 8)
 
ax3 = plt.subplot(gs[1, 0:3])
ax3.plot(df_new_build['date'],df_new_build['new_build'])
ax3.set_title('New Private Housing Structures Authorized by Building Permits for Los Angeles County', fontsize = 8)
ax3.set_xlabel('Year', fontsize = 9)
ax3.set_ylabel('Units', fontsize = 9)

ax4 = plt.subplot(gs[1, 3:6])
ax4.plot(df_mortgage['date'],df_mortgage['mortgage'])
ax4.set_title('30-Year Fixed Rate Mortgage Average in the United States', fontsize = 9)
ax4.set_xlabel('Year', fontsize = 9)
ax4.set_ylabel('Percent', fontsize = 9)
 
ax5 = plt.subplot(gs[2, :3])
ax5.plot(df_pcpi['date'],df_pcpi['pcpi'])
ax5.set_title('Per Capita Personal Income in Los Angeles County', fontsize = 9)
ax5.set_xlabel('Year', fontsize = 9)
ax5.set_ylabel('Dollars', fontsize = 9)

ax6 = plt.subplot(gs[2, 3:6])
ax6.plot(df_cpi['date'],df_cpi['cpi'])
ax6.set_title('Consumer price index of the United States', fontsize = 9)
ax6.set_xlabel('Year', fontsize = 9)
ax6.set_ylabel('Percent', fontsize = 9)

plt.show()

# %% [markdown]
# <a id='2.2.2.3'></a>
# #### 2.2.2.3 Findings from Raw Data Ploting
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# * __How are the data distributed?__
# 1. The date ranges in each dataset are different but similar, but all datasets cover the years from 1990 to 2020.
# 2. The interval of data in each dataset varies from weekly to monthly to yearly.
# 3. The six datasets can be merged by date features after date interval adjustment.
#
# * __What are some common trends?__
# 1. Most features are positively correlated with home price.
# 2. Only mortgage interest rate is negatively correlated with home price.
#
# * __What are the relationships between variables in your datasets?__
# 1. All these features seem affect the home price in LA county.
# 2. Raw CPI data reflects the percentage of growth rate and needs to be converted into a base value index to accomplish analysis.

# %%
#OVERVIEW YOUR QUESTION AND PERFORM YOUR ANALYSIS IN THIS SECTION

# %% [markdown]
# <a id='2.3'></a>
# ## Step 3:  Identify 1-3 research questions and perform analysis
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>
# Now that you have a better understanding of the data, you will want to form a research question which is interesting to you. The research question should be broad enough to be of interest to a reader but narrow enough that the question can be answered with the data.  Some examples:
#
# * __Too Narrow:__  What is the GDP of the U.S. for 2011?  This is just asking for a fact or a single data point.
#
# * __Too Broad:__  What is the primary reason for global poverty?  This could be a Ph.D. thesis and would still be way too broad.  What data will you use to answer this question?  Even if a single dataset offered an answer, would it be defendable given the variety of datasets out there?
#
# * __Good:__  Can you use simple sentiment analysis on comments about movies in a movie database to predict its box office earnings?  If you have, or can obtain, data on a variety of movies and you have their box office earnings, this is a question which you can potentially answer well.
#
# __Remember__, this course is for learning Python. You will not be graded on the complexity, accuracy or performance of your analytical methods. However, you are expected to use a Python library, e.g., _scikitlearn_, successfully to generate results and explain why you picked the methods you used.

# %% [markdown]
# <a id='2.3.1'></a>
# ### 2.3.1 Research Questions
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# * __QUESTION 1:__
# Can you use statistical analysis to verify whether the rumor “Housing prices are determined by population in the long term, by land supply in the medium term, and by the economy in the short term” is correct or not? And among these features, which feature has the most impact on Single Family home prices in Los Angeles county?
#
# * __QUESTION 2:__
# If the per capita personal income in Los Angeles County increases to $93,000 in 2030 and inflation has not improved for 9 years, can you build a model and predict the median single-family home price in Los Angeles County in 2030?

# %% [markdown]
# <a id='2.3.2'></a>
# ### 2.3.2 Perform Analysis
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.3.2.1'></a>
# #### 2.3.2.1 Clean and Transform Datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## Clean and Transform df_median
df_median['date'] = pd.to_datetime(df_median['date']).dt.to_period('M')
df_median = df_median[(df_median['date'] >= '1990') & (df_median['date'] < '2021')]
## Intercept coincident years
df_median = df_median[['date','median']]
## keep useful column to make analysis clear
df_median['date'] = pd.to_datetime(df_median['date'].astype(str))
## reformat date column to datetime format

## Clean and Transform df_population
df_population['date'] = pd.to_datetime(df_population['date']).dt.to_period('M')
df_population = df_population[(df_population['date'] >= '1990') & (df_population['date'] <= '2021')]
## Intercept coincident years
df_population = df_population.set_index('date').resample('M').ffill().reset_index()
## spread and copy yearly data to each month of the year
df_population.drop([len(df_population)-1],inplace=True)
df_population['date'] = pd.to_datetime(df_population['date'].astype(str))
## reformat date column to datetime format

## Clean and Transform df_new_build
df_new_build['date'] = pd.to_datetime(df_new_build['date']).dt.to_period('M')
df_new_build = df_new_build[(df_new_build['date'] >= '1990') & (df_new_build['date'] <= '2021')]
## Intercept coincident years
df_new_build = df_new_build.set_index('date').resample('M').ffill().reset_index()
## spread and copy yearly data to each month of the year
df_new_build.drop([len(df_new_build)-1],inplace = True)
df_new_build['date'] = pd.to_datetime(df_new_build['date'].astype(str))
## reformat date column to datetime format

## Clean and Transform df_mortgage
df_mortgage['date'] = pd.to_datetime(df_mortgage['date']).dt.to_period('M')
df_mortgage=df_mortgage[(df_mortgage['date'] >= '1990') & (df_mortgage['date'] < '2021')]
## Intercept coincident years
df_mortgage = df_mortgage[['date','mortgage']].groupby(['date']).agg({'mortgage':'mean'}).reset_index()
## spread weekly data to their month of the year, use mean value of each month
df_mortgage['date'] = pd.to_datetime(df_mortgage['date'].astype(str))
## reformat date column to datetime format

## Clean and Transform df_pcpi
df_pcpi['date'] = pd.to_datetime(df_pcpi['date']).dt.to_period('M')
df_pcpi = df_pcpi[(df_pcpi['date'] >= '1990') & (df_pcpi['date'] <= '2021')]
## Intercept coincident years
df_pcpi = df_pcpi.set_index('date').resample('M').ffill().reset_index()
## spread and copy yearly data to each month of the year
df_pcpi.drop([len(df_pcpi)-1],inplace = True)
df_pcpi['date'] = pd.to_datetime(df_pcpi['date'].astype(str))
## reformat date column to datetime format

## Clean and Transform df_cpi
df_cpi['date']=pd.to_datetime(df_cpi['index']).dt.to_period('M')
df_cpi = df_cpi.rename(columns = {'United States':'cpi'})
df_cpi = df_cpi[(df_cpi['date'] >= '1990') & (df_cpi['date'] <= '2021')]
## Intercept coincident years
df_cpi.reset_index(inplace=True)
df_cpi = df_cpi[['date','cpi']]
cpi_2020_percent = df_cpi['cpi'].values.tolist()[-2]
## create percentage cpi in 2020 for future learning use
df_cpi.loc[0,['cpi']] = 1
#convert df_cpi.cpi to base value index, assuming cpi in 1990 is 1
for i in range(1,len(df_cpi)):
    df_cpi.loc[i,['cpi']] = df_cpi.cpi[i-1]*((100+df_cpi.cpi[i])/100)
df_cpi=df_cpi.set_index('date').resample('M').ffill().reset_index()
## spread and copy yearly data to each month of the year
cpi_2020_value = df_cpi['cpi'].values.tolist()[-2]
## create base value cpi in 2020 for future learning use
df_cpi.drop([len(df_cpi)-1],inplace=True)
df_cpi['date'] = pd.to_datetime(df_cpi['date'].astype(str))
## reformat date column to datetime format
df_cpi['cpi'] = df_cpi['cpi'].astype(float)

# %% [markdown]
# <a id='2.3.2.2'></a>
# #### 2.3.2.2 Plot Cleaned and Transformed Datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## plot six Cleaned and Transformed Datasets after rescaling 'date' data to monthly
fig = plt.figure(figsize =([10, 20]))

gs = plt.GridSpec(6, 6)
gs.update(wspace = 2, hspace =0.4)

ax1 = plt.subplot(gs[0, :3])
ax1.plot(df_median['date'],df_median['median'])
ax1.set_title('Median Prices of Existing Single Family Homes in Los Angeles county', fontsize = 9)
ax1.set_xlabel('Year', fontsize = 9)
ax1.set_ylabel('median', fontsize = 9)

ax2 = plt.subplot(gs[1, :3])
ax2.plot(df_population['date'],df_population['population'])
ax2.set_title('Resident Population in Los Angeles County', fontsize = 9)
ax2.set_xlabel('Year', fontsize = 9)
ax2.set_ylabel('Thousands of Persons', fontsize = 8)
 
ax3 = plt.subplot(gs[2, :3])
ax3.plot(df_new_build['date'],df_new_build['new_build'])
ax3.set_title('New Private Housing Structures Authorized by Building Permits for Los Angeles County', fontsize = 8)
ax3.set_xlabel('Year', fontsize = 9)
ax3.set_ylabel('Units', fontsize = 9)

ax4 = plt.subplot(gs[0, 3:6])
ax4.plot(df_mortgage['date'],df_mortgage['mortgage'])
ax4.set_title('30-Year Fixed Rate Mortgage Average in the United States', fontsize = 9)
ax4.set_xlabel('Year', fontsize = 9)
ax4.set_ylabel('Percent', fontsize = 9)
 
ax5 = plt.subplot(gs[1, 3:6])
ax5.plot(df_pcpi['date'],df_pcpi['pcpi'])
ax5.set_title('Per Capita Personal Income in Los Angeles County', fontsize = 9)
ax5.set_xlabel('Year', fontsize = 9)
ax5.set_ylabel('Dollars', fontsize = 9)

ax6 = plt.subplot(gs[2, 3:6])
ax6.plot(df_cpi['date'],df_cpi['cpi'])
ax6.set_title('Consumer price index of the United States', fontsize = 9)
ax6.set_xlabel('Year', fontsize = 9)
ax6.set_ylabel('Base Value Index', fontsize = 9)

plt.show()
## the data interval of six datasets are all monthly now, and data range is unified.
## So the plot would look very different from the previous one

# %% [markdown]
# <a id='2.3.2.3'></a>
# #### 2.3.2.3 Merge Six Datasets
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
#Merge six datasets and create df_all as a integrated dataset
df_all = pd.merge(df_median, df_population, how = "outer", on = ['date'])
df_all = pd.merge(df_all, df_new_build, how = "outer", on = ['date'])
df_all = pd.merge(df_all, df_pcpi, how = "outer", on = ['date'])
df_all = pd.merge(df_all, df_cpi, how = "outer", on = ['date'])
df_all = pd.merge(df_all, df_mortgage, how = "outer", on = ['date'])
df_all_ForPlot = df_all.copy(deep = True)
df_all.info()
## to check the data types of new datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 0 to 371
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        372 non-null    datetime64[ns]
#  1   median      372 non-null    float64
#  2   population  372 non-null    float64
#  3   new_build   372 non-null    float64
#  4   pcpi        372 non-null    int64
#  5   cpi         372 non-null    float64
#  6   mortgage    372 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 23.2 KB

# %%
## double check merged dataset has no NaN/Null
df_all.isna().sum()
# Out:
# date          0
# median        0
# population    0
# new_build     0
# pcpi          0
# cpi           0
# mortgage      0
# dtype: int64

# %%
## use pairplot to look briefly for the relationship between features
sns.pairplot(df_all,
             corner = True,
             diag_kind = 'kde',
             kind = 'reg',
             markers = '+',
             plot_kws = {'line_kws':{'color':'red','alpha':0.5}},
             height = 1.5
            )

# %% [markdown]
# <a id='2.3.2.4'></a>
# #### 2.3.2.4 Solving Question 1
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.3.2.4.1'></a>
# ##### 2.3.2.4.1 Analyse Long-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## sample 1990-2020, same as the range of df_all, chack correlations between features
df_all.corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# pcpi          0.839666
# cpi           0.806184
# population    0.770993
# mortgage      0.703197
# new_build     0.650397
# Name: median, dtype: float64

# %% [markdown]
# <a id='2.3.2.4.2'></a>
# ##### 2.3.2.4.2 Analyse Medium-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## sample 1996-2005, chack correlations between features
df_all[df_all.date.ge('1995') & df_all.date.lt('2005')
      ].corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# new_build     0.891235
# cpi           0.874461
# pcpi          0.856215
# population    0.827365
# mortgage      0.782225
# Name: median, dtype: float64

# %%
## sample 2005-2015, chack correlations between features
df_all[df_all.date.ge('2005') & df_all.date.lt('2015')
      ].corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# new_build     0.877783
# mortgage      0.624843
# cpi           0.526697
# pcpi          0.358210
# population    0.352367
# Name: median, dtype: float64

# %% [markdown]
# <a id='2.3.2.4.3'></a>
# ##### 2.3.2.4.3 Analyse Short-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## sample 2000-2003, chack correlations between features
df_all[df_all.date.ge('2000') & df_all.date.lt('2003')
      ].corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# mortgage      0.834772
# population    0.792622
# pcpi          0.771236
# cpi           0.766470
# new_build     0.343059
# Name: median, dtype: float64

# %%
## sample 1996-1999, chack correlations between features
df_all[df_all.date.ge('1996') & df_all.date.lt('1999')
      ].corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# mortgage      0.537879
# pcpi          0.507576
# population    0.492442
# cpi           0.453173
# new_build     0.451789
# Name: median, dtype: float64

# %%
df_all[df_all.date.ge('2010') & df_all.date.lt('2013')
      ].corr(method = 'pearson')['median'].abs().sort_values(ascending = False)[1:]
# Out:
# mortgage      0.481163
# pcpi          0.092778
# population    0.091096
# cpi           0.049359
# new_build     0.033847
# Name: median, dtype: float64

# %% [markdown]
# <a id='2.3.2.4.4'></a>
# ##### 2.3.2.4.4 why particular methods were chosen
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# The relationship between each column is quasi linear and independent. The variables in each column are continuous, numerical and normally distributed. So I use correlation method to find out whether a relationship exists between each dataset and then determining the magnitude and action of that relationship.
#
# And the Pearson correlation measures the strength of the linear relationship between two variables, so I use __Pearson correlation method__ for analysis.

# %% [markdown]
# <a id='2.3.2.5'></a>
# #### 2.3.2.5 Solving Question 2
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.3.2.5.1'></a>
# ##### 2.3.2.5.1 Transform Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## Convert 'date' column format to float in df_all
df_all['date_temp'] = 0
for i in range(0,len(df_all.date)):
    df_all.loc[i,['date_temp']] = df_all.date.dt.year[i]+df_all.date.dt.month[i]/12.01
## rescale 12 month into decimal
## use 12.01 to rescale to avoid carring month to the integer of next year
    
df_all.drop(columns = 'date',inplace = True)
df_all = df_all.rename(columns = {'date_temp':'date'})
df_all.head(13)
## take look at the result of rescaling month data in 'date' column to decimal
# Out:
#            median  population  new_build   pcpi      cpi  mortgage  \
# 0   215337.926006    8878.157    25125.0  21510  1.00000    9.8950
# 1   208399.117906    8878.157    25125.0  21510  1.00000   10.1975
# 2   208134.862749    8878.157    25125.0  21510  1.00000   10.2680
# 3   219003.989632    8878.157    25125.0  21510  1.00000   10.3700
# 4   209065.024168    8878.157    25125.0  21510  1.00000   10.4775
# 5   210605.895742    8878.157    25125.0  21510  1.00000   10.1640
# 6   225250.714143    8878.157    25125.0  21510  1.00000   10.0350
# 7   213478.489676    8878.157    25125.0  21510  1.00000   10.1000
# 8   211552.002447    8878.157    25125.0  21510  1.00000   10.1750
# 9   207801.384318    8878.157    25125.0  21510  1.00000   10.1775
# 10  202716.814957    8878.157    25125.0  21510  1.00000   10.0140
# 11  212855.455029    8878.157    25125.0  21510  1.00000    9.6725
# 12  197706.413753    8948.125    15914.0  21602  1.04235    9.6375
#
#            date
# ...

# %%
df_all.info()
## to check the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 0 to 371
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   median      372 non-null    float64
#  1   population  372 non-null    float64
#  2   new_build   372 non-null    float64
#  3   pcpi        372 non-null    int64
#  4   cpi         372 non-null    float64
#  5   mortgage    372 non-null    float64
#  6   date        372 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# <a id='2.3.2.5.2'></a>
# ##### 2.3.2.5.2 Build Learning Model
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
features = ['date','pcpi','cpi']
## because only date, 'pcpi' and 'cpi' is highly(>80%) correlated with 'median',
## so I only choose thses three features to make model
target = 'median'
X = df_all[features]
y = df_all[target]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=67)
## Split data

model = LinearRegression()
model.fit(X_train, y_train)
## making Linear Regression model

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)
coefficients = model.coef_
intercept = model.intercept_
print("coefficients:")
for i, name in enumerate(X_train.columns):
    print(f'{name:>12}: {model.coef_[i]}')  
print("intercept:",model.intercept_,'\n')
## output coefficients and intercept

y_pred_train=model.predict(X_train)
mse_train=mean_squared_error(y_pred_train, y_train)
print('The MSE of the training data is:',mse_train)
r2_train=r2_score(y_pred_train, y_train)
print('The r2 of the training data is:',r2_train,'\n')
## check MSE and r2 score of training data

y_pred_test=model.predict(X_test)
mse_test=mean_squared_error(y_pred_test, y_test)
print('The MSE of the testing data is:',mse_test)
r2_test=r2_score(y_pred_test, y_test)
print('The r2 of the testing data is:',r2_test)
## check MSE and r2 score of testing data
# Out:
# coefficients:
#         date: 5798.838031771687
#         pcpi: 13.347223704060983
#          cpi: -347039.4238975837
# intercept: -11276674.444278223
#
# The MSE of the training data is: 6288122181.057103
# The r2 of the training data is: 0.6207357444183743
#
# The MSE of the testing data is: 7955241809.803582
# The r2 of the testing data is: 0.5478009212540933

# %% [markdown]
# <a id='2.3.2.5.3'></a>
# ##### 2.3.2.5.3 why particular methods were chosen
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# The relationship between each column is quasi linear. The data in the datasets are all numerical, and there is a target variable 'median single-family home price' needs to be predicted. The linear regression model can capture the relationship between input variables and a numerical output. So I decide to use __linear regression model__ from sci-kit-learn library to proceed the analysis.
#
# The findings of question 1 indicated that, for long-term (1990-2020) data statistic analysis, only per capita personal income and base value CPI data is highly correlated with median single-family home price in Los Angeles County. So I use date, per capita personal income and base value CPI data as features data, median single-family home price as target data to learn and build model.

# %% [markdown]
# <a id='2.4'></a>
# ## Step 4:  Present Your Findings
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>
#
# In this step, you can begin to report your findings.  What did you learn from the data and how do your findings help answer your research question?  Use _matplotlib_ visualizations to present these findings.
#
#
# __Remember:__ Rarely will a single data analysis conclusively answer a research question.  Here, you need to identify possible limitations.  For example, are your results limited to a certain area, city, or country?  Are you making assumptions about the data which may, or may not, be valid (e.g., that students in one term are equally qualified as students in another)?  Document these limitations in a few paragraphs.

# %%
#EXPAND THIS SECTION TO PRESENT YOUR FINDINGS

# %% [markdown]
# <a id='2.4.1'></a>
# ### 2.4.1 Findings for Question 1
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.4.1.1'></a>
# #### 2.4.1.1 Plot Long-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
#Correlation of each features over a 30-year cycle (1990-2020)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot.corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 30-year cycle (1990-2020)')
plt.tight_layout()
plt.show()

# %% [markdown]
# __Findings:__ For the long term  (with a 30-year sample), in Los Angeles County, per capita personal income, consumer price index are all highly correlated with median prices of single family homes.

# %% [markdown]
# <a id='2.4.1.2'></a>
# #### 2.4.1.2 Plot Medium-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
#Correlation of each features over a 10-year cycle (1995-2005)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot[df_all_ForPlot.date.ge('1995') &\
                           df_all_ForPlot.date.lt('2005')
                          ].\
            corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 10-year cycle (1995-2005)')
plt.tight_layout()
plt.show()

# %%
#Correlation of each features over a 10-year cycle (2005-2015)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot[df_all_ForPlot.date.ge('2005') &\
                           df_all_ForPlot.date.lt('2015')
                          ].\
            corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 10-year cycle (2005-2015)')
plt.tight_layout()
plt.show()

# %% [markdown]
# __Findings:__ For the medium term  (with two 10-year samples), in Los Angeles County, new private housing structures authorized by building permits is highly correlated with median prices of single family homes.

# %% [markdown]
# <a id='2.4.1.3'></a>
# #### 2.4.1.3 Plot Short-term Correlation of Each Features
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
#Correlation of each features over a 3-year cycle (1996-1999)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot[df_all_ForPlot.date.ge('1996') &\
                           df_all_ForPlot.date.lt('1999')
                          ].\
            corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 3-year cycle (1996-1999)')
plt.tight_layout()
plt.show()

# %%
#Correlation of each features over a 3-year cycle (2000-2003)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot[df_all_ForPlot.date.ge('2000') &\
                           df_all_ForPlot.date.lt('2003')
                          ].\
            corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 3-year cycle (2000-2003)')
plt.tight_layout()
plt.show()

# %%
#Correlation of each features over a 3-year cycle (2010-2013)
plt.figure(figsize = (6,5))
sns.heatmap(df_all_ForPlot[df_all_ForPlot.date.ge('2010') &\
                           df_all_ForPlot.date.lt('2013')
                          ].\
            corr(method = 'pearson').abs(),
            annot = True,
            fmt = ".2f",
            linewidths = 1,
            cmap = sns.color_palette('rocket')
           )
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of each features over a 3-year cycle (2010-2013)')
plt.tight_layout()
plt.show()

# %% [markdown]
# __Findings:__ For the short term  (with three 3-year samples), in Los Angeles County, 30-Year Fixed Rate Mortgage is mostly correlated with median prices of single family homes.

# %% [markdown]
# <a id='2.4.1.4'></a>
# #### 2.4.1.4 Summary of Question 1 Analysis
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# After statistical analysis, I can find that the rumor among real estate investors “_Housing prices are determined by population in the long term, by land supply in the medium term, and by the economy in the short term_” is __partially correct__ for Los angeles county.
#
# For population,I used resident population data; for land supply, I used new private housing structures authorized by building permits data; and by economy, I used 30-Year Fixed Rate Mortgage Average in the United States data, Per Capita Personal Income data and World Consumer Price Index data.I assumed 30 years as long term, 10 years as medium term, and 3 years as short term.
#
# For the long term, I took a 30-year sample (1990-2020), per capita personal income, consumer price index are all highly correlated (84% and 81%) with median prices of single family homes in Los Angeles County. The resident population is only medium-highly correlated (77%) with median prices of single family homes in Los Angeles County.
# For the medium term, I took two 10-year samples (1995-2005, 2005-2015), only new private housing structures authorized by building permits is highly correlated (89% and 88%) with median prices of single family homes in Los Angeles County.
# For the short term, I took three 3-year samples(1996-1999, 2000-2003, 2010-2013), only 30-Year Fixed Rate Mortgage is mostly correlated (54%, 83% and 48%) with median prices of single family homes in Los Angeles County.
#
# Among these features, the per capita personal income feature has the greatest long-term impact on single-family home prices in Los Angeles County.
#
# Therefore, in Los Angeles county, for long-term real estate investment, we should follow closely to per capita personal income and inflation rate; for medium-term real estate investment, we should focus on land supply; for short-term real estate investment, we need to pay attention to the mortgage interest rate.

# %% [markdown]
# <a id='2.4.2'></a>
# ### 2.4.2 Findings for Question 2
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# <a id='2.4.2.1'></a>
# #### 2.4.2.1 Plot Learning Model
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
## Plot learning model vs scatter actual median price
xs = np.linspace(df_all.date.min(),df_all.date.max())
bO = model.intercept_
b1 = model.coef_[0]
ys = bO + (b1 * xs)

fig, ax = plt.subplots(figsize = (8,5))
ax.scatter(X.date,
           y,
           c = 'navy',
           alpha = 0.5,
           s = 5,
           label = 'single-family home Median price'
          )
ax.plot(xs,
        ys,
        label = 'Linear Regression model',
        c = 'steelblue'
       )
for x_i, y_i in zip(X.date, y):
    ax.plot([x_i, x_i],
            [y_i, b1*x_i+bO],
            c = 'gray',
            linestyle = 'dashed',
            alpha = 0.1
           )
ax.set_xlabel('year')
ax.set_ylabel('Dollars')
ax.set_title('The Linear Regression model of single-family home Median price in Los Angeles County')
plt.legend()

# %%
## take look at how predicted training data distributed
plt.hist(y_pred_train)
# Out:
# (array([81., 58., 24., 45., 24., 11., 19., 18.,  8.,  9.]),
#  array([195698.85804087, 243147.01409008, 290595.17013928, 338043.32618849,
#         385491.4822377 , 432939.6382869 , 480387.79433611, 527835.95038532,
#         575284.10643452, 622732.26248373, 670180.41853294]),
#  <BarContainer object of 10 artists>)

# %%
## scatterplot for both training and testing data to visualize how the prediction line looks
fig, ax = plt.subplots(figsize=(8,6))

plt.scatter(y_train, y_pred_train,
          c = 'gray', marker = 'o', s = 25, alpha = 0.3,
          label = 'Train data')

plt.scatter(y_test, y_pred_test,
          c = 'blue', marker = 'o', s = 25, alpha = 0.4,
          label = 'Test data')

ax.set_xlabel('Actual values')
ax.set_ylabel('Predicted values')
ax.set_title('Predict Training and Testing Data Visualization')
plt.legend(loc = 'upper left')

# %% [markdown]
# <a id='2.4.2.2'></a>
# #### 2.4.2.2 Predict Data
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %%
cpi_2030_value=cpi_2020_value*(((100+cpi_2020_percent)/100)**10)
## calculate base value CPI in 2030 by using percentage CPI in 2020 and base value CPI in 2020

print('If the CPI increase rate in the United States remains unchanged since 2020,', 
      'the base value CPI in 2030 can be calculated as:\n',
      cpi_2030_value
     )

print('\ntThe predicted median single-family home price in Los Angeles County in 2030 is:\n$',
      model.predict(np.array([2030,
                              93000,
                              cpi_2030_value
                             ]).reshape(1,-1)
                   )[0].round(2)
     )
## assuming per capita personal income in Los Angeles County increases to $93,000 in 2030
## using model to make prediction on median home price
# Out:
# If the CPI increase rate in the United States remains unchanged since 2020, the base value CPI in 2030 can be calculated as:
#  2.2391956360497107
#
# tThe predicted median single-family home price in Los Angeles County in 2030 is:
# $ 959169.4
# /home/ch3ngp3ng/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# <a id='2.4.2.3'></a>
# #### 2.4.2.3 Summary of Question 2 Analysis
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# The relationship between each column is quasi linear. The data in the datasets are all numerical, and there is a target variable 'median single-family home price' needs to be predicted. The linear regression model can capture the relationship between input variables and a numerical output. So I decide to use __linear regression model__ from sci-kit-learn library to proceed the analysis.
#
# The findings of question 1 indicated that, for long-term (1990-2020) data statistic analysis, only per capita personal income and base value CPI data is highly correlated with median single-family home price in Los Angeles County. So I use date, per capita personal income and base value CPI data as features data, median single-family home price as target data to learn and build model.
#
# If the CPI increase rate in the United States remains unchanged since 2020, and if the CPI in 2020 set as 1, then the base value CPI in 2030 can be calculated as 2.2391956360497107. Using the linear regression model, I assume that the per capita personal income in Los Angeles County increases to $93,000 in 2030. Then the model predicted median single-family home price in Los Angeles County in 2030 is __959169.4__ Dollars

# %% [markdown]
# <a id='2.4.3'></a>
# ### 2.4.3 Limitations of Analysis
# <sub style="font-size:small"><div align="right">[Back to Table of Contents](#0)</div></sub>

# %% [markdown]
# Because the datasets I used for this analysis are primarily for Los Angeles county, my results are limited to Los Angeles County. Then in other locations or regions, for question 1, the saying I tried to verify may or may not to be correct; for question 2, the models and predictions may also be different.
