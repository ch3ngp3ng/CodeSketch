# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from random import randint
import datetime
import os
import time
import pandas as pd

# URL of the campsite availability page on Recreation.gov
url = 'https://www.recreation.gov/camping/campgrounds/234717'
response = requests.get(url)
page = response.text
time.sleep(10)
soup = BeautifulSoup(page,"html")

# Find the element that contains the availability information
availability_element = soup.find_all()

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>ERROR: The request could not be satisfied</title>
# </head><body>
# <h1>403 ERROR</h1>
# <h2>The request could not be satisfied.</h2>
# <hr noshade="" size="1px"/>
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <br clear="all"/>
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <br clear="all"/>
# <hr noshade="" size="1px"/>
# <pre>
# Generated by cloudfront (CloudFront)
# Request ID: ZoFCkr_HpxBhbmVuttRfOGvq2F5zvSL2PRiiOFubt9PxEfnAXe6I8g==
# </pre>
# <address>
# </address>
# </body></html>

# %%
availability_element
# Out:
# [<html><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <title>ERROR: The request could not be satisfied</title>
#  </head><body>
#  <h1>403 ERROR</h1>
#  <h2>The request could not be satisfied.</h2>
#  <hr noshade="" size="1px"/>
#  Request blocked.
#  We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
#  <br clear="all"/>
#  If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
#  <br clear="all"/>
#  <hr noshade="" size="1px"/>
#  <pre>
#  Generated by cloudfront (CloudFront)
#  Request ID: GLtBEUgA0hdvA1JUAernBakEYd3ptxUgJF7Ib_CJfj6dg1z0s8AbVA==
#  </pre>
#  <address>
#  </address>
#  </body></html>,
#  <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
<tr class="row-selected " id="90459"><th class="site-id-wrap camping-site-name-cell" scope="row"><a href="https://www.recreation.gov/camping/campsites/90459" target="_blank" rel="noopener noreferrer" aria-label="Open Site 15 in a new tab" class="rec-availability-item">15 </a></th><td><div class="camp-location-name">Drippi<div class="camp-location-name--icon"><button data-component="Button" type="button" class="sarsa-button sarsa-help-tip sarsa-button-subtle sarsa-button-sm" aria-expanded="false"><span class="sarsa-button-inner-wrapper"><span aria-hidden="true" class="sarsa-button-icon-content left-icon is-only-child"><svg data-component="Icon" class="sarsa-icon rec-icon-more-horiz" viewBox="0 0 24 24" role="presentation" focusable="false" height="24" width="24"><g><path d="M6 10c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm12 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2zm-6 0c-1.1 0-2 .9-2 2s.9 2 2 2 2-.9 2-2-.9-2-2-2z"></path></g></svg></span><span class="sarsa-button-content"></span></span></button></div></div></td><td class="unavailable"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 14, 2023 - Site 15 is Not Available">X</button></div></td><td class="unavailable"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 15, 2023 - Site 15 is Not Available">X</button></div></td><td class="unavailable"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 16, 2023 - Site 15 is Reserved">R</button></div></td><td class="unavailable"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 17, 2023 - Site 15 is Reserved">R</button></div></td><td class="start"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 18, 2023 - Site 15 - Selection start date."><svg data-component="Icon" class="sarsa-icon rec-icon-check" viewBox="0 0 24 24" role="presentation" focusable="false" height="24" width="24"><g><path d="M9 16.17L4.83 12l-1.42 1.41L9 19 21 7l-1.41-1.41z"></path></g></svg></button></div></td><td class="end"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 19, 2023 - Site 15 - Selection end date. Click to remove the entire selection."><svg data-component="Icon" class="sarsa-icon rec-icon-check" viewBox="0 0 24 24" role="presentation" focusable="false" height="24" width="24"><g><path d="M9 16.17L4.83 12l-1.42 1.41L9 19 21 7l-1.41-1.41z"></path></g></svg><span class="rec-end-date-close"></span></button></div></td><td class="available"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 20, 2023 - Site 15 is available">A</button></div></td><td class="available"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 21, 2023 - Site 15 is available">A</button></div></td><td class="available"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 22, 2023 - Site 15 is available">A</button></div></td><td class="available"><div class="rec-full-button-wrap"><button class="rec-availability-date" aria-label="Jun 23, 2023 - Site 15 is available">A</button></div></td></tr>

# %%
# Extract the availability text if the element is found
if availability_element:
    availability_text = availability_element.get_text(strip=True)
    print('Campsite Availability:', availability_text)
else:
    print('Campsite availability not found.')
# Out:
# Campsite availability not found.
